# %%
import pandas as pd
import numpy as np
import random 
from sklearn.preprocessing import LabelEncoder
CSV_PATH="extracted_styles.csv"
df=pd.read_csv(CSV_PATH)
random_seed=47
df
# Out:
#                   author          song                style_feature_category  \
# 0    Петре М. Андреевски  Наопачно оро                     Фигуративен јазик
# 1    Петре М. Андреевски  Наопачно оро                              Сарказам
# 2    Петре М. Андреевски  Наопачно оро                  Фрагмент од реченица
# 3    Петре М. Андреевски  Наопачно оро               Долга реченица (run-on)
# 4    Петре М. Андреевски  Наопачно оро                          Активен глас
# ..                   ...           ...                                   ...
# 995      Матеја Матевски      Патување  Зборови поврзани со храна или јадење
# 996      Матеја Матевски      Патување              Зборови поврзани со смрт
# 997      Матеја Матевски      Патување   Зборови поврзани со самоповредување
# 998      Матеја Матевски      Патување                    Сексуална содржина
# 999      Матеја Матевски      Патување    Зборови поврзани со слободно време
#
# ...

# %%
pattern = r'^Да' 
df[df['extracted_text'].str.match(pattern, na=False)]
# Out:
#                   author          song            style_feature_category  \
# 0    Петре М. Андреевски  Наопачно оро                 Фигуративен јазик
# 7    Петре М. Андреевски  Наопачно оро                     Машки заменки
# 8    Петре М. Андреевски  Наопачно оро                    Женски заменки
# 12   Петре М. Андреевски  Наопачно оро  Прикажување меѓучовечки конфликт
# 16   Петре М. Андреевски  Наопачно оро             Говор за постигнување
# ..                   ...           ...                               ...
# 876        Анте Поповски        Коледе             Говор за постигнување
# 880        Анте Поповски        Коледе         Сè или ништо размислување
# 887        Анте Поповски        Коледе                            Пцовки
# 958      Матеја Матевски      Патување  Прикажување меѓучовечки конфликт
# 962      Матеја Матевски      Патување             Говор за постигнување
#
#                                         extracted_text  time_needed
# ...

# %%
total_time=df['time_needed'].sum()
print(f'Total time {total_time} sec, {total_time/60} min')
# Out:
# Total time 2691.154917240143 sec, 44.85258195400238 min
