# %%
import pandas as pd

# Path to your CSV
csv_file = "output.csv"

# Load into DataFrame
df = pd.read_csv(csv_file, encoding="utf-8")

# %%
df
# Out:
#                Source         Author  Context Additional_Context  \
# 0    Лебедовата Песна   Адам Гајтани      NaN   ЛЕБЕДОВАТА ПЕСНА
# 1    Лебедовата Песна   Адам Гајтани      NaN    ЗЕЛЕНИОТ ПАСТУВ
# 2    Лебедовата Песна   Адам Гајтани      NaN    ЗЕЛЕНИОТ ПАСТУВ
# 3    Лебедовата Песна   Адам Гајтани      NaN    ЗЕЛЕНИОТ ПАСТУВ
# 4    Лебедовата Песна   Адам Гајтани      NaN    ЗЕЛЕНИОТ ПАСТУВ
# ..                ...            ...      ...                ...
# 984             СРЕДЕ  Ристо Лазаров      NaN          Аргетинци
# 985             СРЕДЕ  Ристо Лазаров      NaN          Аргетинци
# 986             СРЕДЕ  Ристо Лазаров      NaN          Аргетинци
# 987             СРЕДЕ  Ристо Лазаров      NaN          Аргетинци
# 988             СРЕДЕ  Ристо Лазаров      NaN          Аргетинци
#
#            Song title                                               Song
# 0    ЛЕБЕДОВАТА ПЕСНА  ЛЕБЕДОВАТА ПЕСНА \n \nЈас не знам од кај ми е ...
# ...
