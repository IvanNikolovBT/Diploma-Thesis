# %%
import pandas as pd
import numpy as np
import random 
from sklearn.preprocessing import LabelEncoder
CSV_PATH="author_songs_created_only_with_styles.csv"
df=pd.read_csv(CSV_PATH)
random_seed=47
df
# Out:
#                   author                      song_title  \
# 0    Петре М. Андреевски  УШТЕ ЕДНИ ПОДАТОЦИ ЗА ДЕНИЦИЈА
# 1    Петре М. Андреевски                 Првата разделба
# 2    Петре М. Андреевски                            1903
# 3    Петре М. Андреевски                        ЛЕТУВАЊЕ
# 4    Петре М. Андреевски                           ИЗЛЕТ
# ..                   ...                             ...
# 280        Ристо Лазаров                        САНТЕЛМО
# 281        Ристо Лазаров             МАЦЕДОНИО ФЕРНАНДЕЗ
# 282        Ристо Лазаров                 СРЕБРЕНАТА РЕКА
# 283        Ристо Лазаров                         ТАНТЕЛА
# 284        Ристо Лазаров                          БОРХЕС
#
#                                        styles_to_apply  \
# 0    Фигуративен јазик: Да\nСарказам: Не\nФрагмент ...
# 1    Фигуративен јазик: Да\nСарказам: Не\nФрагмент ...
# 2    Фигуративен јазик: Да\nСарказам: Не\nФрагмент ...
# ...

# %%
df['ms'].sum()
# Out:
# np.int64(1162254)
