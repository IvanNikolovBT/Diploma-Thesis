# %%
import pandas as pd
import numpy as np
import random 
from sklearn.preprocessing import LabelEncoder
CSV_PATH="classification/cleaned_songs.csv"
df_og=pd.read_csv(CSV_PATH)
random_seed=47
df_og
# Out:
#                    author                                            context  \
# 0     Петре М. Андреевски  Петок е прекрасен ден за читање поезија, па за...
# 1              Кочо Рацин  На 13 јуни 1943 година загинал Кочо Рацин. И п...
# 2         Гане Тодоровски  На 22 мај 2010 година починал еден од најголем...
# 3          Владо Урошевиќ  Денес на блогот читаме прекрасни македонски ст...
# 4              Кочо Рацин  Денес е 1 Мај, Меѓународен ден на трудот. Во т...
# ...                   ...                                                ...
# 1194        Ристо Лазаров                                                NaN
# 1195        Ристо Лазаров                                                NaN
# 1196        Ристо Лазаров                                                NaN
# 1197        Ристо Лазаров                                                NaN
# 1198        Ристо Лазаров                                                NaN
#
#      additional_context             song_title  \
# 0                   NaN           Наопачно оро
# 1                   NaN  Балада за непознатиот
# 2                   NaN                Молитва
# 3                   NaN                Слобода
# 4                   NaN               Копачите
# ...                 ...                    ...
# 1194          Аргетинци                  ЕВИТА
# 1195          Аргетинци                 ГАРДЕЛ
# 1196          Аргетинци                 БОРХЕС
# 1197          Аргетинци                 САБАТО
# 1198          Аргетинци                 РГЕРИЧ
#
#                                               song_text           source
# 0     Наопачно оро – Петре М. Андреевски\n\nКој игра...  song_kafe_kniga
# 1     Балада за непознатиот – Кочо Рацин\n\nНатаму –...  song_kafe_kniga
# 2     Молитва – Гане Тодоровски\n\n(пред крајот на г...  song_kafe_kniga
# 3     Слобода – Влада Урошевиќ\n\nПтица со пет крила...  song_kafe_kniga
# 4     Копачите – Кочо Рацин\n\nСе к’ти ноќта црна!\n...  song_kafe_kniga
# ...                                                 ...              ...
# 1194  ЕВИТА  \n \nветриштата од западните пампаси  \...            СРЕДЕ
# 1195  ГАРДЕЛ \n \nа зина уста \nа птици ќе си ги рас...            СРЕДЕ
# 1196  БОРХЕС \n \nза жал светот с# уште е стварен  \...            СРЕДЕ
# 1197  САБАТО  \n \nво сантос лагоресу законите на фи...            СРЕДЕ
# 1198  РГЕРИЧ \n  \nмузиката е скривалиште за птици  ...            СРЕДЕ
#
# [1199 rows x 6 columns]

# %%
import pandas as pd
import numpy as np
import random 
from sklearn.preprocessing import LabelEncoder
CSV_PATH="author_songs_created_only_with_styles.csv"
df=pd.read_csv(CSV_PATH)
random_seed=47
df
# Out:
#                   author                      song_title  \
# 0    Петре М. Андреевски  УШТЕ ЕДНИ ПОДАТОЦИ ЗА ДЕНИЦИЈА
# 1    Петре М. Андреевски                 Првата разделба
# 2    Петре М. Андреевски                            1903
# 3    Петре М. Андреевски                        ЛЕТУВАЊЕ
# 4    Петре М. Андреевски                           ИЗЛЕТ
# ..                   ...                             ...
# 250        Ристо Лазаров                        САНТЕЛМО
# 251        Ристо Лазаров             МАЦЕДОНИО ФЕРНАНДЕЗ
# 252        Ристо Лазаров                 СРЕБРЕНАТА РЕКА
# 253        Ристо Лазаров                         ТАНТЕЛА
# 254        Ристо Лазаров                          БОРХЕС
#
#                                        styles_to_apply  \
# 0    - Активен глас- Долга реченица (run-on)- Женск...
# 1    - Активен глас- Анксиозност- Бидување несигуре...
# 2    - Активен глас- Броеви- Долга реченица (run-on...
# 3    - Активен глас- Долга реченица (run-on)- Женск...
# 4    - Активен глас- Бидување несигурен/колеблив- Б...
# ..                                                 ...
# 250  - Активен глас- Анксиозност- Долга реченица (r...
# 251  - Активен глас- Бидување несигурен/колеблив- Б...
# 252  - Активен глас- Зборови поврзани со аудитивна ...
# 253  - Активен глас- Зборови поврзани со визуелна п...
# 254  - Активен глас- Долга реченица (run-on)- Зборо...
#
#                       name_of_new_song  \
# 0                  Тајната на минатото
# 1              Тага на исчезнатиот ден
# 2    Смртта и ризикот на нашите денови
# 3          Песна за минатото на смртта
# 4           Песна за спомени и звукови
# ..                                 ...
# 250             Темнината на спомените
# 251         Песна за Заборавената Дома
# 252       Песна на времето и спомените
# 253                   Ветер на Спомени
# 254                   Ветер на спомени
#
#                                               new_song  input_tokens  \
# 0    Тајната на минатото\n\nТи, моја љубов, ми го о...           419
# 1    Тага на исчезнатиот ден\n\nО, денот што беше, ...           460
# 2    Смртта и ризикот на нашите денови\n\nОд ден на...           545
# 3    Песна за минатото на смртта\n\nТи, мината љубо...           435
# 4    Песна за спомени и звукови\n\nОд денот кога ти...           624
# ..                                                 ...           ...
# 250  Темнината на спомените\n\nВо сенките на минато...           395
# 251  Песна за Заборавената Дома\n\nВо тишината на в...           475
# 252  Песна на времето и спомените\n\nВо ритамот на ...           357
# 253  Ветер на Спомени\n\nВетерот мисли, а очите гле...           335
# 254  Ветер на спомени\n\nВетерот шепоти, тихо, како...           396
#
#      output_tokens  total_tokens    ms
# 0             1668          2087  7759
# 1              650          1110  3569
# 2              694          1239  4533
# 3             1240          1675  6175
# 4              954          1578  4758
# ..             ...           ...   ...
# 250            806          1201  4223
# 251            840          1315  4455
# 252            483           840  3122
# 253            403           738  2573
# 254            816          1212  5162
#
# [255 rows x 9 columns]

# %%
df['ms'].sum()
# Out:
# np.int64(964509)

# %%
import pandas as pd
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter
import re

def analyze_author_text(csv_path, min_df=2, max_df=0.8, n_top_words=10, stop_words=None):

    df = pd.read_csv(csv_path)
    df['song_text'] = df['song_text'].str.lower().str.replace(r'[^\w\s]', '', regex=True)
    
    author_corpus = df.groupby("author")["song_text"].apply(lambda x: " ".join(x)).reset_index()
    
    results = {'common_words': {}, 'expressive_words': {}}
    
    for author in author_corpus['author']:
        texts = df[df['author'] == author]['song_text']
        all_words = ' '.join(texts).split()
        author_names = author.lower().split()
        author_first_name = author_names[0] if len(author_names) > 0 else ''
        author_last_name = author_names[-1] if len(author_names) > 1 else ''
        
        if stop_words:
            all_words = [word for word in all_words if word not in stop_words]
        all_words = [word for word in all_words if word not in [author_first_name, author_last_name]]
        
        word_counts = Counter(all_words)
        common_words = [(word, count) for word, count in word_counts.most_common(n_top_words)]
        results['common_words'][author] = common_words
    
    vectorizer = TfidfVectorizer(
        min_df=min_df,
        max_df=max_df,
        stop_words=stop_words,
        ngram_range=(1, 1)
    )
    X = vectorizer.fit_transform(author_corpus["song_text"])
    feature_names = vectorizer.get_feature_names_out()
    
    for idx, author in enumerate(author_corpus["author"]):
        author_names = author.lower().split()
        author_first_name = author_names[0] if len(author_names) > 0 else ''
        author_last_name = author_names[-1] if len(author_names) > 1 else ''
        
        tfidf_vector = X[idx].toarray()[0]
        top_indices = tfidf_vector.argsort()[-n_top_words*2:][::-1]  
        top_terms = [(feature_names[i], tfidf_vector[i]) for i in top_indices 
                     if feature_names[i] not in [author_first_name, author_last_name]]
        top_terms = top_terms[:n_top_words]  
        results['expressive_words'][author] = top_terms
    
    print("Most Common Words per Author (Raw Frequency):")
    for author, words in results['common_words'].items():
        print(f"\n{author}:")
        for word, count in words:
            print(f"  {word}: {count}")
    
    print("\nMost Expressive Words per Author (TF-IDF Scores):")
    for author, words in results['expressive_words'].items():
        print(f"\n{author}:")
        for word, score in words:
            print(f"  {word}: {score:.3f}")
    
    return results

# Example usage
if __name__ == "__main__":
    # Example stop words to filter out
    custom_stop_words = ['the', 'and', 'to', 'of', 'a']
    results = analyze_author_text(
        csv_path="classification/cleaned_songs.csv",
        min_df=2,
        max_df=0.8,
        n_top_words=10,
        stop_words=custom_stop_words
    )
# Out:
# Most Common Words per Author (Raw Frequency):
#
# Јован Котески:
#   да: 6
#   ко: 5
#   на: 4
#   април: 3
#   што: 3
#   љубена: 2
#   и: 2
#   заспи: 1
#   сред: 1
#   зелена: 1
#
# Јосип Коцев:
#   во: 22
#   и: 22
#   на: 17
#   со: 14
#   ќе: 12
#   што: 11
#   сме: 10
#   не: 9
#   си: 9
#   колку: 9
#
# Адам Гајтани:
#   на: 237
#   се: 160
#   во: 138
#   и: 128
#   од: 113
#   со: 100
#   го: 86
#   ја: 81
#   да: 77
#   не: 63
#
# Анте Поповски:
#   и: 86
#   да: 59
#   на: 47
#   се: 43
#   од: 42
#   во: 39
#   не: 31
#   го: 28
#   ќе: 26
#   што: 26
#
# Ацо Караманов:
#   и: 17
#   ќе: 14
#   на: 12
#   во: 12
#   да: 8
#   со: 8
#   ти: 6
#   се: 5
#   а: 5
#   нè: 5
#
# Ацо Шопов:
#   и: 190
#   на: 122
#   во: 93
#   од: 77
#   се: 61
#   што: 56
#   да: 55
#   со: 48
#   ќе: 35
#   не: 32
#
# Блаже Конески:
#   и: 492
#   да: 410
#   се: 358
#   на: 348
#   во: 253
#   со: 195
#   што: 194
#   не: 187
#   од: 175
#   е: 171
#
# Богомил Ѓузел:
#   да: 361
#   и: 359
#   на: 297
#   што: 283
#   во: 223
#   од: 193
#   не: 182
#   се: 169
#   за: 134
#   како: 130
#
# Бранко Цветкоски:
#   во: 105
#   се: 92
#   на: 90
#   и: 89
#   од: 77
#   да: 43
#   со: 36
#   што: 33
#   не: 33
#   ќе: 28
#
# Братислав Ташковски:
#   и: 139
#   да: 137
#   во: 96
#   на: 84
#   што: 80
#   за: 63
#   се: 60
#   не: 58
#   ќе: 58
#   е: 55
#
# Ванчо Николески:
#   в: 7
#   и: 6
#   не: 5
#   песна: 4
#   се: 4
#   млади: 4
#   на: 4
#   без: 4
#   ке: 4
#   мила: 3
#
# Веле Смилевски:
#   на: 259
#   во: 210
#   од: 98
#   се: 87
#   што: 85
#   за: 69
#   со: 66
#   ја: 64
#   и: 61
#   книга: 57
#
# Видое Подгорец:
#   во: 9
#   е: 8
#   и: 8
#   да: 5
#   нека: 5
#   се: 5
#   од: 5
#   зборови: 4
#   љубов: 4
#   си: 4
#
# Владо Урошевиќ:
#   и: 186
#   се: 182
#   на: 160
#   во: 139
#   што: 124
#   од: 99
#   како: 83
#   да: 71
#   не: 58
#   со: 46
#
# Гане Тодоровски:
#   на: 99
#   и: 93
#   да: 80
#   се: 61
#   со: 60
#   за: 51
#   во: 44
#   ти: 37
#   што: 36
#   го: 32
#
# Гого Ивановски:
#   се: 5
#   минуат: 4
#   и: 4
#   в: 4
#   со: 3
#   на: 3
#   колоната: 2
#   жено: 2
#   рече: 2
#   селанец: 2
#
# Ефтим Клетников:
#   на: 395
#   и: 377
#   во: 306
#   се: 213
#   од: 207
#   што: 143
#   го: 120
#   да: 102
#   е: 91
#   ја: 84
#
# Игор Исаковски:
#   и: 54
#   се: 50
#   да: 48
#   како: 45
#   од: 44
#   во: 42
#   на: 33
#   со: 27
#   ме: 25
#   ќе: 24
#
# Катица Ќулавкова:
#   и: 369
#   на: 307
#   се: 255
#   да: 232
#   не: 178
#   во: 178
#   од: 162
#   што: 137
#   за: 108
#   е: 106
#
# Коле Неделковски:
#   и: 13
#   да: 11
#   в: 10
#   се: 7
#   на: 7
#   кој: 7
#   од: 6
#   не: 6
#   ми: 5
#   во: 4
#
# Константин Миладинов:
#   да: 17
#   и: 15
#   ја: 14
#   не: 9
#   ми: 7
#   в: 7
#   си: 7
#   бисеро: 6
#   ти: 6
#   ке: 6
#
# Кочо Рацин:
#   и: 117
#   на: 99
#   да: 73
#   се: 52
#   не: 50
#   в: 39
#   од: 39
#   по: 39
#   за: 37
#   со: 32
#
# Лилјана Дирјан:
#   и: 39
#   се: 27
#   со: 17
#   на: 15
#   во: 14
#   за: 12
#   е: 11
#   не: 8
#   од: 7
#   го: 7
#
# Матеја Матевски:
#   и: 140
#   на: 108
#   што: 70
#   во: 63
#   од: 56
#   се: 53
#   да: 36
#   со: 34
#   ти: 30
#   ме: 29
#
# Милош Линдро:
#   и: 215
#   на: 124
#   се: 89
#   од: 83
#   во: 57
#   со: 50
#   го: 46
#   за: 41
#   е: 36
#   ќе: 33
#
# Никола Вапцаров:
#   в: 8
#   ќе: 8
#   се: 7
#   земја: 6
#   и: 5
#   таа: 4
#   ја: 4
#   не: 3
#   со: 3
#   над: 3
#
# Никола Маџиров:
#   ќе: 9
#   го: 5
#   еден: 3
#   ден: 3
#   се: 3
#   и: 3
#   во: 3
#   со: 3
#   нè: 2
#   како: 2
#
# Петре М. Андреевски:
#   и: 420
#   што: 263
#   во: 200
#   на: 198
#   се: 189
#   да: 186
#   не: 139
#   од: 125
#   за: 120
#   како: 97
#
# Пијан Славеј:
#   да: 343
#   и: 298
#   се: 281
#   на: 248
#   ќе: 228
#   не: 189
#   во: 186
#   од: 128
#   го: 122
#   што: 120
#
# Раде Силјан:
#   на: 23
#   и: 10
#   си: 9
#   имаме: 9
#   да: 8
#   за: 6
#   со: 6
#   време: 5
#   од: 5
#   во: 4
#
# Радован Павловски:
#   во: 7
#   на: 6
#   се: 5
#   и: 4
#   сите: 3
#   врата: 3
#   пред: 3
#   што: 3
#   од: 2
#   пауза: 2
#
# Рајко Жинзифов:
#   и: 10
#   на: 9
#   ја: 8
#   глас: 6
#   сја: 6
#   ти: 5
#   е: 4
#   за: 4
#   в: 4
#   то: 4
#
# Ристо Лазаров:
#   на: 232
#   и: 158
#   во: 150
#   од: 137
#   се: 125
#   да: 91
#   си: 45
#   со: 45
#   не: 45
#   за: 43
#
# Славко Јаневски:
#   в: 358
#   и: 283
#   на: 154
#   се: 109
#   ќе: 107
#   од: 103
#   да: 101
#   во: 98
#   со: 96
#   за: 95
#
# Тихомир Јанчовски:
#   и: 14
#   се: 11
#   да: 10
#   не: 9
#   на: 8
#   е: 7
#   го: 7
#   во: 7
#   ја: 4
#   како: 4
#
# Тодор Чаловски:
#   на: 167
#   во: 141
#   и: 136
#   да: 126
#   од: 86
#   го: 85
#   што: 77
#   со: 65
#   ја: 48
#   се: 48
#
# Цане Андреевски:
#   и: 19
#   на: 18
#   во: 15
#   ги: 10
#   за: 7
#   што: 7
#   како: 6
#   е: 6
#   езеро: 5
#   ме: 5
#
# Most Expressive Words per Author (TF-IDF Scores):
#
# Јован Котески:
#   април: 0.424
#   ко: 0.395
#   љубена: 0.304
#   млаз: 0.165
#   питом: 0.152
#   заспи: 0.152
#   гулаб: 0.141
#   стада: 0.141
#   пожар: 0.133
#   крвав: 0.133
#
# Јосип Коцев:
#   април: 0.286
#   колку: 0.271
#   сме: 0.260
#   какви: 0.254
#   ко: 0.224
#   бил: 0.170
#   оди: 0.156
#   овој: 0.150
#   атом: 0.134
#   свет: 0.132
#
# Адам Гајтани:
#   еден: 0.171
#   една: 0.149
#   те: 0.132
#   му: 0.119
#   јас: 0.113
#   седум: 0.107
#   смртта: 0.099
#   мојата: 0.094
#   божилото: 0.094
#   беше: 0.087
#
# Анте Поповски:
#   една: 0.129
#   само: 0.127
#   зашто: 0.118
#   нешта: 0.108
#   таа: 0.105
#   тие: 0.098
#   еве: 0.095
#   нас: 0.095
#   беше: 0.094
#   себеси: 0.092
#
# Ацо Караманов:
#   верувај: 0.207
#   нè: 0.187
#   тргнеме: 0.148
#   пушки: 0.138
#   дојдеш: 0.138
#   железо: 0.130
#   можеби: 0.120
#   нека: 0.112
#   топи: 0.111
#   бура: 0.111
#
# Ацо Шопов:
#   стари: 0.239
#   старо: 0.221
#   ме: 0.141
#   ко: 0.140
#   те: 0.123
#   сите: 0.122
#   девет: 0.101
#   небо: 0.098
#   крви: 0.094
#   јас: 0.088
#
# Блаже Конески:
#   јас: 0.250
#   ме: 0.195
#   сум: 0.163
#   дека: 0.154
#   те: 0.151
#   само: 0.139
#   песна: 0.135
#   тој: 0.135
#   но: 0.123
#   тие: 0.115
#
# Богомил Ѓузел:
#   ce: 0.394
#   но: 0.209
#   ни: 0.199
#   нè: 0.187
#   сал: 0.161
#   сме: 0.149
#   нас: 0.144
#   или: 0.140
#   зар: 0.139
#   ако: 0.129
#
# Бранко Цветкоски:
#   над: 0.169
#   сè: 0.134
#   под: 0.123
#   мојот: 0.115
#   враќа: 0.114
#   ме: 0.113
#   без: 0.113
#   зад: 0.103
#   оној: 0.100
#   водата: 0.097
#
# Братислав Ташковски:
#   сум: 0.251
#   секогаш: 0.220
#   тоа: 0.206
#   јас: 0.192
#   љубовта: 0.171
#   сè: 0.161
#   дека: 0.161
#   ме: 0.130
#   сакам: 0.125
#   повеќе: 0.121
#
# Ванчо Николески:
#   ке: 0.259
#   млади: 0.247
#   борци: 0.216
#   мила: 0.204
#   гора: 0.185
#   партизани: 0.179
#   дебарца: 0.179
#   солнце: 0.179
#   собрал: 0.164
#   песна: 0.143
#
# Веле Смилевски:
#   книга: 0.379
#   забрането: 0.336
#   книгата: 0.284
#   ѕид: 0.264
#   co: 0.242
#   додека: 0.186
#   забранета: 0.162
#   ѕверот: 0.141
#   пред: 0.130
#   под: 0.129
#
# Видое Подгорец:
#   нека: 0.237
#   наместо: 0.233
#   зборови: 0.196
#   плени: 0.188
#   љубов: 0.184
#   убави: 0.156
#   јазик: 0.147
#   мака: 0.141
#   капки: 0.124
#   лик: 0.116
#
# Владо Урошевиќ:
#   градот: 0.269
#   низ: 0.210
#   дожд: 0.196
#   зад: 0.146
#   среде: 0.138
#   врз: 0.134
#   таа: 0.119
#   само: 0.116
#   кој: 0.115
#   сè: 0.112
#
# Гане Тодоровски:
#   ој: 0.284
#   те: 0.192
#   ли: 0.185
#   одиме: 0.175
#   низ: 0.156
#   колку: 0.149
#   јас: 0.140
#   до: 0.119
#   стануваш: 0.092
#   уште: 0.089
#
# Гого Ивановски:
#   селанец: 0.243
#   жено: 0.243
#   негде: 0.205
#   брат: 0.180
#   нивниот: 0.180
#   рече: 0.160
#   мајчински: 0.142
#   осмев: 0.142
#   опи: 0.142
#   притаил: 0.142
#
# Ефтим Клетников:
#   но: 0.166
#   мракот: 0.161
#   само: 0.153
#   низ: 0.149
#   темниот: 0.147
#   му: 0.144
#   детето: 0.137
#   сè: 0.131
#   над: 0.124
#   ни: 0.114
#
# Игор Исаковски:
#   ме: 0.241
#   боли: 0.230
#   нека: 0.187
#   додека: 0.185
#   ајде: 0.184
#   денеска: 0.174
#   врз: 0.172
#   кога: 0.154
#   дожд: 0.151
#   те: 0.150
#
# Катица Ќулавкова:
#   без: 0.191
#   кога: 0.164
#   ни: 0.154
#   она: 0.131
#   меѓу: 0.131
#   само: 0.130
#   сè: 0.129
#   кој: 0.123
#   би: 0.110
#   значи: 0.106
#
# Коле Неделковски:
#   колни: 0.304
#   нити: 0.210
#   страден: 0.210
#   кој: 0.191
#   младост: 0.174
#   вијат: 0.152
#   везден: 0.151
#   либе: 0.140
#   немам: 0.139
#   та: 0.120
#
# Константин Миладинов:
#   ке: 0.346
#   тамо: 0.319
#   видам: 0.263
#   мразој: 0.240
#   бисер: 0.231
#   крилја: 0.220
#   грло: 0.211
#   ела: 0.205
#   моме: 0.205
#   мило: 0.193
#
# Кочо Рацин:
#   ли: 0.204
#   лист: 0.136
#   живот: 0.135
#   ни: 0.120
#   човек: 0.118
#   гроб: 0.116
#   гради: 0.115
#   кој: 0.114
#   денови: 0.108
#   срце: 0.107
#
# Лилјана Дирјан:
#   некако: 0.206
#   концерт: 0.135
#   таа: 0.132
#   ниту: 0.128
#   ме: 0.121
#   мајка: 0.119
#   огледалото: 0.109
#   pinterest: 0.109
#   илјада: 0.109
#   ама: 0.103
#
# Матеја Матевски:
#   ме: 0.242
#   ни: 0.141
#   пред: 0.132
#   ѕвони: 0.118
#   каде: 0.112
#   патот: 0.100
#   сум: 0.100
#   сега: 0.097
#   низ: 0.095
#   однеси: 0.093
#
# Милош Линдро:
#   до: 0.207
#   небо: 0.152
#   сите: 0.151
#   тие: 0.139
#   тоа: 0.138
#   него: 0.137
#   таму: 0.137
#   земни: 0.136
#   но: 0.130
#   седумте: 0.125
#
# Никола Вапцаров:
#   земја: 0.295
#   таа: 0.186
#   безброј: 0.145
#   те: 0.143
#   над: 0.136
#   пролет: 0.135
#   крај: 0.125
#   истај: 0.119
#   далек: 0.119
#   јонков: 0.119
#
# Никола Маџиров:
#   еден: 0.212
#   ден: 0.207
#   ветрот: 0.191
#   остават: 0.182
#   образи: 0.182
#   лубеница: 0.182
#   раскажува: 0.182
#   пеперутките: 0.182
#   уживајте: 0.182
#   граничен: 0.182
#
# Петре М. Андреевски:
#   кога: 0.230
#   беше: 0.227
#   таа: 0.213
#   сите: 0.185
#   кај: 0.182
#   те: 0.172
#   јас: 0.172
#   меѓу: 0.160
#   нејзината: 0.154
#   ме: 0.145
#
# Пијан Славеј:
#   те: 0.288
#   ме: 0.261
#   ако: 0.169
#   љубов: 0.143
#   сум: 0.142
#   јас: 0.130
#   кога: 0.128
#   дека: 0.120
#   нема: 0.117
#   верувам: 0.112
#
# Раде Силјан:
#   имаме: 0.534
#   време: 0.178
#   воздивнува: 0.172
#   матеја: 0.172
#   јавето: 0.147
#   спомените: 0.138
#   болно: 0.114
#   сакам: 0.109
#   народ: 0.101
#   глава: 0.097
#
# Радован Павловски:
#   пауза: 0.320
#   врата: 0.292
#   седи: 0.231
#   пред: 0.182
#   сите: 0.168
#   прелета: 0.160
#   претставата: 0.160
#   случила: 0.160
#   сочувај: 0.160
#   затворената: 0.160
#
# Рајко Жинзифов:
#   то: 0.354
#   стани: 0.265
#   глас: 0.249
#   нива: 0.236
#   невиден: 0.207
#   иди: 0.190
#   божји: 0.177
#   бој: 0.149
#   мене: 0.114
#   неговата: 0.113
#
# Ристо Лазаров:
#   среде: 0.218
#   две: 0.173
#   одново: 0.152
#   под: 0.145
#   дека: 0.133
#   нема: 0.129
#   секој: 0.127
#   ем: 0.125
#   до: 0.123
#   уште: 0.117
#
# Славко Јаневски:
#   село: 0.168
#   ко: 0.146
#   кај: 0.144
#   песна: 0.132
#   чедо: 0.125
#   ме: 0.121
#   гради: 0.118
#   ој: 0.117
#   те: 0.116
#   ни: 0.115
#
# Тихомир Јанчовски:
#   чувствуваме: 0.209
#   умира: 0.207
#   чекам: 0.198
#   есен: 0.151
#   кога: 0.150
#   собата: 0.132
#   те: 0.126
#   денови: 0.118
#   доаѓа: 0.110
#   свест: 0.104
#
# Тодор Чаловски:
#   нѐ: 0.334
#   ни: 0.181
#   до: 0.174
#   кога: 0.144
#   те: 0.123
#   низ: 0.106
#   нас: 0.105
#   кон: 0.105
#   пред: 0.094
#   сѐ: 0.091
#
# Цане Андреевски:
#   порти: 0.255
#   езеро: 0.235
#   сончевите: 0.213
#   оставете: 0.199
#   видот: 0.153
#   стебло: 0.153
#   лето: 0.153
#   тука: 0.153
#   јавата: 0.142
#   тишината: 0.141
